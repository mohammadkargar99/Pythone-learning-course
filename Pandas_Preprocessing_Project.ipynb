# %% [markdown]
# # Exercises Python KNTU
#
# * Name: Mohammad Kargar-gazkoh
# * EMail: mohammadkargargazkoh@gmail.com
# * GitHub: https://github.com/mohammadkargar99

# %% [markdown]
# # Pandas_Preprocessing_Project

# %%
import numpy as np
import pandas as pd

# %%
DF = pd.read_csv("files/Churn_Modelling_preprocessing.csv")
DF
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## 1. detect NAN values:

# %%
DF.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname             True
# CreditScore        False
# Geography           True
# Gender              True
# Age                False
# Tenure              True
# Balance             True
# NumOfProducts       True
# HasCrCard           True
# IsActiveMember      True
# EstimatedSalary     True
# Exited              True
# dtype: bool

# %%
DF.mode().head()
# Out:
#    RowNumber  CustomerId Surname  CreditScore Geography Gender   Age  Tenure  \
# 0          1    15565701   Smith        850.0    France   Male  37.0     2.0
# 1          2    15565706     NaN          NaN       NaN    NaN  38.0     NaN
# 2          3    15565714     NaN          NaN       NaN    NaN   NaN     NaN
# 3          4    15565779     NaN          NaN       NaN    NaN   NaN     NaN
# 4          5    15565796     NaN          NaN       NaN    NaN   NaN     NaN
#
#   Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0       0            1.0        1.0             1.0         24924.92     0.0
# 1     NaN            NaN        NaN             NaN              NaN     NaN
# 2     NaN            NaN        NaN             NaN              NaN     NaN
# 3     NaN            NaN        NaN             NaN              NaN     NaN
# 4     NaN            NaN        NaN             NaN              NaN     NaN

# %%
DF.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age       Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  9999.000000
# mean    5000.50000  1.569094e+07    650.528800     38.929300     5.013101
# std     2886.89568  7.193619e+04     96.653299     10.557227     2.892162
# min        1.00000  1.556570e+07    350.000000    -10.000000     0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000     3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000     5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000     7.000000
# max    10000.00000  1.581569e+07    850.000000    150.000000    10.000000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count    9999.000000  9999.000000     9998.000000      9993.000000
# mean        1.530053     0.605361        0.514703    100087.362910
# std         0.581498    10.017931        0.500209     57500.952876
# ...

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          9998 non-null   object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        9998 non-null   object
#  5   Gender           9996 non-null   object
#  6   Age              10000 non-null  int64
#  7   Tenure           9999 non-null   float64
#  8   Balance          9999 non-null   object
#  9   NumOfProducts    9999 non-null   float64
#  10  HasCrCard        9999 non-null   float64
#  11  IsActiveMember   9998 non-null   float64
#  12  EstimatedSalary  9993 non-null   float64
#  13  Exited           9999 non-null   float64
# dtypes: float64(6), int64(4), object(4)
# memory usage: 1.1+ MB

# %%
#Surname
DF.dropna(subset = ['Surname'], inplace=True)

#Geography
DF['Geography'].fillna(DF['Geography'].mode()[0], inplace = True)

#Gender
DF.dropna(subset = ['Gender'], inplace=True)

#Tenure
DF['Tenure'].fillna(DF['Tenure'].mode()[0], inplace = True)

#Balance
DF.dropna(subset = ['Balance'], inplace=True)

#NumOfProducts
DF['NumOfProducts'].fillna(DF['NumOfProducts'].mode()[0], inplace = True)

#HasCrCard
DF['HasCrCard'].fillna(DF['HasCrCard'].mode()[0], inplace = True)

#IsActiveMember
DF['IsActiveMember'].fillna(DF['IsActiveMember'].mode()[0], inplace = True)

#EstimatedSalary
DF['EstimatedSalary'].fillna(DF['EstimatedSalary'].mean(), inplace = True)

#Exited
DF['Exited'].fillna(DF['Exited'].mode()[0], inplace = True)

# %%
print(f'Is there any null values in dataset?? {DF.isnull().any().values.any()}')
# Out:
# Is there any null values in dataset?? False

# %% [markdown]
# ***

# %% [markdown]
# ## 2. Inconsistent Data:

# %%
for col in DF.columns:
    print(f'{col :30s} >>>>      {DF[col].unique()}')
# Out:
# RowNumber                      >>>>      [    1     2     3 ...  9998  9999 10000]
# CustomerId                     >>>>      [15634602 15647311 15619304 ... 15584532 15682355 15628319]
# Surname                        >>>>      ['Hargrave' 'Hill' 'Onio' ... 'Kashiwagi' 'Aldridge' 'Burbidge']
# CreditScore                    >>>>      [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
# ...

# %%
#Geography
DF['Geography'].replace(to_replace=['3','4','56','Pooya','10000'], value=DF['Geography'].mode()[0], inplace=True)

#Gender
DF['Gender'].replace(to_replace=['9','5'], value=DF['Gender'].mode()[0], inplace=True)

#Age
DF['Age'].replace(to_replace=-10, value=DF['Age'].mode()[0], inplace=True)

#HasCaCard
DF['HasCrCard'].replace(to_replace=-1000, value=DF['HasCrCard'].mode()[0], inplace=True)

#IsActiveMember 
DF['IsActiveMember'].replace(to_replace=-1.0, value=DF['IsActiveMember'].mode()[0], inplace=True)

# %%
DF.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure             float64
# Balance             object
# NumOfProducts      float64
# HasCrCard          float64
# IsActiveMember     float64
# EstimatedSalary    float64
# Exited             float64
# dtype: object

# %%
#Balance
index=[]
index.append(DF['Balance'][DF['Balance'] == 'sorry'].index)
index.append(DF['Balance'][DF['Balance'] == 'hi'].index)
DF.drop(index[0], axis=0, inplace=True)
DF.drop(index[1], axis=0, inplace=True)

#Surname
Inconsistent_Surname = list(DF['Surname'][DF['Surname'] == 'H?'].index)
Inconsistent_Surname.append(list(DF['Surname'][DF['Surname'] == 'He'].index))
for i in Inconsistent_Surname:
    DF.drop(i,inplace=True)
DF.head(20)
# Out:
#     RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602   Hargrave          619    France  Female   42
# 1           2    15647311       Hill          608     Spain  Female   41
# 2           3    15619304       Onio          502    France  Female   42
# 3           4    15701354       Boni          699    France  Female   39
# 4           5    15737888   Mitchell          850     Spain  Female   43
# 5           6    15574012        Chu          645     Spain    Male   44
# 6           7    15592531   Bartlett          822    France    Male   50
# 7           8    15656148     Obinna          376   Germany  Female   29
# 10         11    15767821     Bearce          528    France    Male   31
# 11         12    15737173    Andrews          497     Spain    Male   24
# 12         13    15632264        Kay          476    France  Female   34
# 13         14    15691483       Chin          549    France  Female   25
# ...

# %% [markdown]
# :) thanks for checking out
